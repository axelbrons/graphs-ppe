# %%
import pandas as pd

# %%
df = pd.read_csv("../data/SC_Vuln_8label.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0   filename                                               code  \
# 0           0  33790.sol  pragma solidity ^0.4.4;\n\ncontract Token {\n\...
# 1           1  31454.sol  pragma solidity ^0.4.4;\n\ncontract Token {\n\...
# 2           2  40744.sol  contract SendBalance {\n mapping (address => u...
# 3           3  39290.sol  /**\n * Originally from https://github.com/Con...
# 4           4  39358.sol  pragma solidity ^0.4.4;\n\nlibrary ArrayLib{\n...
#
#                         label  label_encoded
# 0  ./Dataset/reentrancy (RE)/              5
# 1  ./Dataset/reentrancy (RE)/              5
# 2  ./Dataset/reentrancy (RE)/              5
# 3  ./Dataset/reentrancy (RE)/              5
# 4  ./Dataset/reentrancy (RE)/              5

# %%
df['label'].unique()
# Out:
# <StringArray>
# [            './Dataset/reentrancy (RE)/',
#  './Dataset/dangerous delegatecall (DE)/',
#        './Dataset/integer overflow (OF)/',
#    './Dataset/timestamp dependency (TP)/',
#  './Dataset/block number dependency (BN)',
#             './Dataset/ether frozen (EF)',
#    './Dataset/ether strict equality (SE)',
#  './Dataset/unchecked external call (UC)']
# Length: 8, dtype: str

# %%
df['label_encoded'].unique()
# Out:
# array([5, 1, 4, 6, 0, 2, 3, 7])

# %%
df_1 = pd.read_csv("../data/dataset_9label_200_v1.csv")

# %%
df_1.head(5)
# Out:
#                                             filename  \
# 0                                           3521.sol
# 1                                            147.sol
# 2                                          35276.sol
# 3                                            283.sol
# 4  0x001a589dda0d6be37632925eaf1256986b2c6ad0_Ora...
#
#                                                 code  \
# 0  pragma solidity ^0.4.24;\n\n \n\n \ncontract E...
# 1  pragma solidity ^0.4.24;\n\ncontract ERC20 {\n...
# 2  pragma solidity 0.4.15;\n\n\n/// @title Multis...
# 3  pragma solidity ^0.4.18;\n\ncontract SafeMath ...
# 4  /*\nCopyright (c) 2015-2016 Oraclize srl, Thom...
#
#                                     label  label_encoded
# 0             ./Dataset/ether frozen (EF)              2
# 1    ./Dataset/ether strict equality (SE)              3
# 2  ./Dataset/unchecked external call (UC)              7
# 3        ./Dataset/integer overflow (OF)/              4
# ...

# %%
df_1['label'].unique()
# Out:
# <StringArray>
# [           './Dataset/ether frozen (EF)',
#    './Dataset/ether strict equality (SE)',
#  './Dataset/unchecked external call (UC)',
#        './Dataset/integer overflow (OF)/',
#                                    'Safe',
#              './Dataset/reentrancy (RE)/',
#    './Dataset/timestamp dependency (TP)/',
#  './Dataset/dangerous delegatecall (DE)/',
#  './Dataset/block number dependency (BN)']
# Length: 9, dtype: str
