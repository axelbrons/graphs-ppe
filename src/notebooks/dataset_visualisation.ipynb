# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # SC_Vuln_8label

# %%
raw = pd.read_csv("/home/axel/Documents/ECE/ING4/Semestre2/ppe/graphs/data/SC_Vuln_8label.csv")

# %%
raw.shape
# Out:
# (4285, 5)

# %%
raw['label'].value_counts()
# Out:
# label
# ./Dataset/reentrancy (RE)/                1218
# ./Dataset/unchecked external call (UC)    1199
# ./Dataset/integer overflow (OF)/           590
# ./Dataset/block number dependency (BN)     406
# ./Dataset/ether strict equality (SE)       366
# ./Dataset/timestamp dependency (TP)/       312
# ./Dataset/dangerous delegatecall (DE)/      97
# ./Dataset/ether frozen (EF)                 97
# Name: count, dtype: int64

# %%
raw['label'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# # dataset_9l_w_v2

# %%
df_9l = pd.read_csv("/home/axel/Documents/ECE/ING4/Semestre2/ppe/graphs/data/dataset_9l_w_v2.csv")

# %%
df_9l.shape
# Out:
# (4068, 4)

# %%
df_9l['label'].value_counts()
# Out:
# label
# Safe                                      1000
# ./Dataset/reentrancy (RE)/                 600
# ./Dataset/unchecked external call (UC)     600
# ./Dataset/integer overflow (OF)/           590
# ./Dataset/block number dependency (BN)     406
# ./Dataset/ether strict equality (SE)       366
# ./Dataset/timestamp dependency (TP)/       312
# ./Dataset/dangerous delegatecall (DE)/      97
# ./Dataset/ether frozen (EF)                 97
# Name: count, dtype: int64

# %% [markdown]
# # dataset_7l_v4

# %%
df_7l = pd.read_csv("/home/axel/Documents/ECE/ING4/Semestre2/ppe/graphs/data/dataset_7l_v4.csv")

# %%
df_7l.shape
# Out:
# (3874, 4)

# %%
df_7l['label'].value_counts()
# Out:
# label
# Safe                                      1000
# ./Dataset/unchecked external call (UC)     600
# ./Dataset/reentrancy (RE)/                 600
# ./Dataset/integer overflow (OF)/           590
# ./Dataset/block number dependency (BN)     406
# ./Dataset/ether strict equality (SE)       366
# ./Dataset/timestamp dependency (TP)/       312
# Name: count, dtype: int64

# %% [markdown]
# # dataset_2l_v1

# %%
df_2l = pd.read_csv("/home/axel/Documents/ECE/ING4/Semestre2/ppe/graphs/data/dataset_2l_v1.csv")

# %%
df_2l.shape
# Out:
# (2000, 4)

# %%
df_2l['label'].value_counts()
# Out:
# label
# Safe          1000
# Vulnerable    1000
# Name: count, dtype: int64

# %% [markdown]
# Pour le v2 c'est la même chose mais on a 4000 safe et 4000 vulnerable.

# %% [markdown]
# # dataset_2l_v2

# %%
df_2l_pq = pd.read_parquet("/home/axel/Documents/ECE/ING4/Semestre2/ppe/graphs/data/dataset_2l_v2.parquet")

# %%
df_2l_pq.shape
# Out:
# (8000, 4)

# %%
df_2l_pq['label'].value_counts()
# Out:
# label
# Vulnerable    4000
# Safe          4000
# Name: count, dtype: int64
